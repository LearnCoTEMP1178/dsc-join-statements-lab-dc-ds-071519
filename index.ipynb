# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import pandas as pd
import sqlite3

# %%
curr = sqlite3.connect('data.sqlite')
c = curr.cursor()

# %%
df = pd.DataFrame(
    c.execute("""
    SELECT *
    FROM sqlite_master 
    WHERE type='table';
""").fetchall()
)
df.columns = [x[0] for x in c.description]
c.description
df
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table  orderdetails  orderdetails         2
# 1  table      payments      payments        28
# 2  table       offices       offices        32
# 3  table     customers     customers        33
# 4  table        orders        orders        38
# 5  table  productlines  productlines        46
# 6  table      products      products        47
# 7  table     employees     employees        56
#
#                                                  sql
# 0  CREATE TABLE `orderdetails` (`orderNumber`, `p...
# 1  CREATE TABLE `payments` (`customerNumber`, `ch...
# 2  CREATE TABLE `offices` (`officeCode`, `city`, ...
# 3  CREATE TABLE `customers` (`customerNumber`, `c...
# 4  CREATE TABLE `orders` (`orderNumber`, `orderDa...
# 5  CREATE TABLE `productlines` (`productLine`, `t...
# 6  CREATE TABLE `products` (`productCode`, `produ...
# 7  CREATE TABLE `employees` (`employeeNumber`, `l...

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
df = pd.DataFrame(c.execute("""
SELECT count(*)
FROM employees
JOIN offices
LIMIT 10
""").fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   employeeNumber   lastName firstName extension  \
# 0           1002     Murphy     Diane     x5800
# 1           1002     Murphy     Diane     x5800
# 2           1002     Murphy     Diane     x5800
# 3           1002     Murphy     Diane     x5800
# 4           1002     Murphy     Diane     x5800
# 5           1002     Murphy     Diane     x5800
# 6           1002     Murphy     Diane     x5800
# 7           1056  Patterson      Mary     x4611
# 8           1056  Patterson      Mary     x4611
# 9           1056  Patterson      Mary     x4611
#
#                             email officeCode reportsTo   jobTitle officeCode  \
# 0    dmurphy@classicmodelcars.com          1            President          1
# 1    dmurphy@classicmodelcars.com          1            President          2
# 2    dmurphy@classicmodelcars.com          1            President          3
# 3    dmurphy@classicmodelcars.com          1            President          4
# 4    dmurphy@classicmodelcars.com          1            President          5
# 5    dmurphy@classicmodelcars.com          1            President          6
# 6    dmurphy@classicmodelcars.com          1            President          7
# 7  mpatterso@classicmodelcars.com          1      1002   VP Sales          1
# 8  mpatterso@classicmodelcars.com          1      1002   VP Sales          2
# 9  mpatterso@classicmodelcars.com          1      1002   VP Sales          3
#
#             city             phone              addressLine1 addressLine2  \
# 0  San Francisco   +1 650 219 4782         100 Market Street    Suite 300
# 1         Boston   +1 215 837 0825          1550 Court Place    Suite 102
# 2            NYC   +1 212 555 3000      523 East 53rd Street      apt. 5A
# 3          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue     Floor #2
# 6         London  +44 20 7877 2041       25 Old Broad Street      Level 7
# 7  San Francisco   +1 650 219 4782         100 Market Street    Suite 300
# 8         Boston   +1 215 837 0825          1550 Court Place    Suite 102
# 9            NYC   +1 212 555 3000      523 East 53rd Street      apt. 5A
#
#         state    country postalCode territory
# 0          CA        USA      94080        NA
# 1          MA        USA      02107        NA
# 2          NY        USA      10022        NA
# 3                 France      75017      EMEA
# 4  Chiyoda-Ku      Japan   102-8578     Japan
# 5              Australia   NSW 2010      APAC
# 6                     UK   EC2N 1HN      EMEA
# 7          CA        USA      94080        NA
# 8          MA        USA      02107        NA
# 9          NY        USA      10022        NA

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!

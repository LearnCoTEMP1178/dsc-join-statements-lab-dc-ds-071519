# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import pandas as pd
import sqlite3

# %%
curr = sqlite3.connect('data.sqlite')
c = curr.cursor()

# %%
df = pd.DataFrame(
    c.execute("""
    SELECT *
    FROM sqlite_master 
    WHERE type='table';
""").fetchall()
)
df.columns = [x[0] for x in c.description]
c.description
df
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table  orderdetails  orderdetails         2
# 1  table      payments      payments        28
# 2  table       offices       offices        32
# 3  table     customers     customers        33
# 4  table        orders        orders        38
# 5  table  productlines  productlines        46
# 6  table      products      products        47
# 7  table     employees     employees        56
#
#                                                  sql
# 0  CREATE TABLE `orderdetails` (`orderNumber`, `p...
# 1  CREATE TABLE `payments` (`customerNumber`, `ch...
# 2  CREATE TABLE `offices` (`officeCode`, `city`, ...
# 3  CREATE TABLE `customers` (`customerNumber`, `c...
# 4  CREATE TABLE `orders` (`orderNumber`, `orderDa...
# 5  CREATE TABLE `productlines` (`productLine`, `t...
# 6  CREATE TABLE `products` (`productCode`, `produ...
# 7  CREATE TABLE `employees` (`employeeNumber`, `l...

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
df = pd.DataFrame(c.execute("""
SELECT employeeNumber, lastName, firstName, employees.officeCode
FROM employees

;
""").fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    employeeNumber   lastName firstName officeCode
# 0            1002     Murphy     Diane          1
# 1            1056  Patterson      Mary          1
# 2            1076   Firrelli      Jeff          1
# 3            1088  Patterson   William          6
# 4            1102     Bondur    Gerard          4
# 5            1143        Bow   Anthony          1
# 6            1165   Jennings    Leslie          1
# 7            1166   Thompson    Leslie          1
# 8            1188   Firrelli     Julie          2
# 9            1216  Patterson     Steve          2
# 10           1286      Tseng  Foon Yue          3
# 11           1323     Vanauf    George          3
# 12           1337     Bondur      Loui          4
# 13           1370  Hernandez    Gerard          4
# 14           1401   Castillo    Pamela          4
# 15           1501       Bott     Larry          7
# 16           1504      Jones     Barry          7
# 17           1611     Fixter      Andy          6
# 18           1612      Marsh     Peter          6
# 19           1619       King       Tom          6
# 20           1621      Nishi      Mami          5
# 21           1625       Kato   Yoshimi          5
# 22           1702     Gerard    Martin          4

# %%
Hint: Combine the employees and offices tables and use a group by.

# %%
df = pd.DataFrame(c.execute("""
SELECT employeeNumber, lastName, firstName, employees.officeCode, offices.officeCode
FROM employees
JOIN offices
USING (officeCode) ;
""").fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    employeeNumber   lastName firstName officeCode officeCode
# 0            1002     Murphy     Diane          1          1
# 1            1056  Patterson      Mary          1          1
# 2            1076   Firrelli      Jeff          1          1
# 3            1088  Patterson   William          6          6
# 4            1102     Bondur    Gerard          4          4
# 5            1143        Bow   Anthony          1          1
# 6            1165   Jennings    Leslie          1          1
# 7            1166   Thompson    Leslie          1          1
# 8            1188   Firrelli     Julie          2          2
# 9            1216  Patterson     Steve          2          2
# 10           1286      Tseng  Foon Yue          3          3
# 11           1323     Vanauf    George          3          3
# 12           1337     Bondur      Loui          4          4
# 13           1370  Hernandez    Gerard          4          4
# 14           1401   Castillo    Pamela          4          4
# 15           1501       Bott     Larry          7          7
# 16           1504      Jones     Barry          7          7
# 17           1611     Fixter      Andy          6          6
# 18           1612      Marsh     Peter          6          6
# 19           1619       King       Tom          6          6
# 20           1621      Nishi      Mami          5          5
# 21           1625       Kato   Yoshimi          5          5
# 22           1702     Gerard    Martin          4          4

# %% [markdown]
# ## Do any offices have no employees?

# %%
df = pd.DataFrame(c.execute("""
/*
SELECT employeeNumber, lastName, firstName, employees.officeCode, offices.officeCode
*/
SELECT *
FROM offices
/*
JOIN employees
USING (officeCode)

WHERE employees.employeeNumber = 1002;
*/

""").fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          1  San Francisco   +1 650 219 4782         100 Market Street
# 1          2         Boston   +1 215 837 0825          1550 Court Place
# 2          3            NYC   +1 212 555 3000      523 East 53rd Street
# 3          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 6          7         London  +44 20 7877 2041       25 Old Broad Street
#
#   addressLine2       state    country postalCode territory
# 0    Suite 300          CA        USA      94080        NA
# 1    Suite 102          MA        USA      02107        NA
# 2      apt. 5A          NY        USA      10022        NA
# 3                              France      75017      EMEA
# 4               Chiyoda-Ku      Japan   102-8578     Japan
# 5     Floor #2              Australia   NSW 2010      APAC
# 6      Level 7                     UK   EC2N 1HN      EMEA

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
